# %%
fig, ax = plt.subplots(1, 2, figsize=(12,5))

ax[0].hist(df_http["ml_score"], bins=40)
ax[0].set_title("HTTP ML scores")

ax[1].hist(df_ssh["ml_score"], bins=40)
ax[1].set_title("SSH ML scores")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, ax = plt.subplots(1, 2, figsize=(12,5))
#       3 ax[0].hist(df_http["ml_score"], bins=40)
#       4 ax[0].set_title("HTTP ML scores")
#
# NameError: name 'plt' is not defined
